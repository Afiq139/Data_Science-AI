# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %%
plt.rcParams['figure.figsize'] = [10,3]
plt.rcParams['figure.dpi'] = 200

# %%
data = pd.read_csv('7_o_IMDB-Movie-Data.csv', nrows=50)
plt.hist(data['Rating'], bins = 20, edgecolor='white', color='orange')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.title('Histogram Plot')
plt.show()

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
plt.scatter(data['Votes'], data['Rating'], color='r')
plt.xlabel('Votes')
plt.ylabel('Rating')
plt.title('Scatter Plot')
plt.show()

# %%
plt.boxplot(data['Rating'])
plt.show()

# %%
genres = data.groupby('Genre').mean()['Rating'].sort_values(ascending=False)
plt.bar(genres.index[:10], genres.values[:10], color='orange')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_852\2586323945.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   genres = data.groupby('Genre').mean()['Rating'].sort_values(ascending=False)
