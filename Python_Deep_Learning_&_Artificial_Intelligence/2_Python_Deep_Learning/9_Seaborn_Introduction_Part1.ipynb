# %%
import seaborn as sns
import matplotlib.pyplot as plt #using to set the figure aesthetics
import pandas as pd #using to load dataset

# %%
data = sns.load_dataset('iris') #iris flower data
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#histogram
plt.rcParams['figure.figsize'] = [10,3]
plt.rcParams['figure.dpi'] = 200

# sns.histplot(x=data['sepal_length'], kde=True, bins=20)
sns.histplot(x='sepal_length',data=data, kde=True, bins=20, hue='species')
plt.xlabel('Sepal Length in cm')
plt.ylabel('Count')
plt.title('Histogram of Sepal Length Iris Dataset')
plt.show()
